# %% [markdown]
# # Import

# %%
# For Kaggle

# Standard Libraries
import sys
import os
import collections

# Data Science Libraries
import pandas as pd
import numpy as np
import optuna

import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# Statistics Libraries
import statsmodels.api as sm
import statsmodels.tsa.api as smt
import statsmodels.graphics.api as smg

# ML Libraries
import sklearn as sk
from sklearn.metrics import mean_absolute_error
import lightgbm as lgb
import xgboost
import catboost

# Project Libraries
import optiver2023

# Configure Visualization
# %matplotlib inline
plt.style.use('bmh')

# Configure Pandas and SKLearn
pd.set_option("display.max_colwidth", 20)
pd.set_option("display.precision", 3)
sk.set_config(display="diagram")

# File Specific Configurations
DATA_DIR = "/kaggle/input/optiver-trading-at-the-close/"
plt.rcParams['figure.dpi'] = 270
START = pd.Timestamp.now()
SEED = 42

# %% [markdown]
# # 2. LightGBM Baseline

# %%
Xy_train = pd.read_csv(DATA_DIR + "train.csv")
Xy_train
# Out:
#          stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 0               0        0                  0       3.181e+06
# 1               1        0                  0       1.666e+05
# 2               2        0                  0       3.029e+05
# 3               3        0                  0       1.192e+07
# 4               4        0                  0       4.475e+05
# ...           ...      ...                ...             ...
# 5237975       195      480                540       2.441e+06
# 5237976       196      480                540       3.495e+05
# 5237977       197      480                540       0.000e+00
# 5237978       198      480                540       1.001e+06
# 5237979       199      480                540       1.884e+06
#
#          imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 0                          1                1.000     1.338e+07        NaN
# 1                         -1                1.000     1.642e+06        NaN
# 2                         -1                1.000     1.819e+06        NaN
# 3                         -1                1.000     1.839e+07        NaN
# 4                         -1                1.000     1.786e+07        NaN
# ...                      ...                  ...           ...        ...
# 5237975                   -1                1.000     2.828e+07      1.000
# 5237976                   -1                1.001     9.188e+06      1.000
# 5237977                    0                0.996     1.273e+07      0.996
# 5237978                    1                0.999     9.477e+07      0.999
# 5237979                   -1                1.002     2.407e+07      1.001
#
#          near_price  bid_price   bid_size  ask_price   ask_size    wap  \
# 0               NaN      1.000   60651.50      1.000    8493.03  1.000
# 1               NaN      1.000    3233.04      1.001   20605.09  1.000
# 2               NaN      0.999   37956.00      1.000   18995.00  1.000
# 3               NaN      1.000    2324.90      1.000  479032.40  1.000
# 4               NaN      0.999   16485.54      1.000     434.10  1.000
# ...             ...        ...        ...        ...        ...    ...
# 5237975       1.000      1.000   32257.04      1.000  319862.40  1.000
# 5237976       1.000      1.001  205108.40      1.001   93393.07  1.001
# 5237977       0.996      0.996   16790.66      0.996  180038.32  0.996
# 5237978       0.999      0.999  125631.72      0.999  669893.00  0.999
# 5237979       1.001      1.002  250081.44      1.002  300167.56  1.002
#
#          target  time_id       row_id
# 0        -3.030        0        0_0_0
# 1        -5.520        0        0_0_1
# 2        -8.390        0        0_0_2
# 3        -4.010        0        0_0_3
# 4        -7.350        0        0_0_4
# ...         ...      ...          ...
# 5237975   2.310    26454  480_540_195
# 5237976  -8.220    26454  480_540_196
# 5237977   1.169    26454  480_540_197
# 5237978  -1.540    26454  480_540_198
# 5237979  -6.530    26454  480_540_199
#
# [5237980 rows x 17 columns]

# %%
# We split the data here, and use them in the following sections

X = Xy_train.query("target.notna()").drop(['row_id', "time_id"], axis=1)
y = X.pop("target")

# %%
y[-y_len:]
# Out:
# 4190346    -0.090
# 4190347    11.621
# 4190348     0.581
# 4190349    -0.070
# 4190350     1.190
#             ...
# 5237975     2.310
# 5237976    -8.220
# 5237977     1.169
# 5237978    -1.540
# 5237979    -6.530
# Name: target, Length: 1047578, dtype: float64

# %%
y[:-y_len],len(y)
# Out:
# (0          -3.03
#  1          -5.52
#  2          -8.39
#  3          -4.01
#  4          -7.35
#             ...
#  4190341   -31.97
#  4190342     4.43
#  4190343     0.55
#  4190344     5.07
#  4190345     6.98
#  Name: target, Length: 4190314, dtype: float64,
#  5237892)

# %%
X_len = int(len(X) * 0.2)
y_len = int(len(y) * 0.2)

X_train, X_valid = X.iloc[:-X_len], X.iloc[-X_len:]
y_train, y_valid = y[:-y_len], y[-y_len:]

# %%
train_data = lgb.Dataset(X_train, label=y_train)
valid_data = lgb.Dataset(X_valid, label=y_valid)

# %% [raw]
# train_data

# %% [markdown]
# ## 2.2. Simplest LightGBM Solution

# %%
#env = optiver2023.make_env()
#iter_test = env.iter_test()

# %%
#model = lightgbm.LGBMRegressor(
#    random_state = SEED, 
#    objective = 'mae', 
#    device_type = 'gpu'
#)

#model.fit(X_train, y_train)

#counter = 0
#for (test, revealed_targets, sample_prediction) in iter_test:
#    sample_prediction['target'] = model.predict(test.drop('row_id', axis = 1))
#    env.predict(sample_prediction)
#    counter += 1

# %%
#config lgbm 
params = {
    'random_state': SEED,
    'device_type': 'GPU',
    'max_depth': 7,
    'num_leaves': 31,
    'n_estimators': 400,
    'objective': 'regression',
    'learning_rate': 1e-2,
    'verbose': 0
}

# %%
model = lgb.train(
    params,
    train_data,
    valid_sets=[train_data, valid_data],
    early_stopping_rounds=50
)
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [1]	training's l2: 91.4073	valid_1's l2: 81.0129
# Training until validation scores don't improve for 50 rounds
# [2]	training's l2: 91.3781	valid_1's l2: 80.9925
# [3]	training's l2: 91.3494	valid_1's l2: 80.9724
# [4]	training's l2: 91.3216	valid_1's l2: 80.9532
# [5]	training's l2: 91.2938	valid_1's l2: 80.934
# [6]	training's l2: 91.267	valid_1's l2: 80.9154
# [7]	training's l2: 91.2407	valid_1's l2: 80.8973
# [8]	training's l2: 91.2147	valid_1's l2: 80.8791
# [9]	training's l2: 91.1889	valid_1's l2: 80.8624
# [10]	training's l2: 91.1638	valid_1's l2: 80.845
# [11]	training's l2: 91.1396	valid_1's l2: 80.828
# [12]	training's l2: 91.1152	valid_1's l2: 80.8118
# [13]	training's l2: 91.0912	valid_1's l2: 80.7969
# [14]	training's l2: 91.0681	valid_1's l2: 80.7812
# [15]	training's l2: 91.0449	valid_1's l2: 80.7669
# [16]	training's l2: 91.0226	valid_1's l2: 80.7514
# [17]	training's l2: 91.0003	valid_1's l2: 80.7362
# [18]	training's l2: 90.979	valid_1's l2: 80.7217
# [19]	training's l2: 90.9574	valid_1's l2: 80.7083
# [20]	training's l2: 90.9368	valid_1's l2: 80.694
# [21]	training's l2: 90.9163	valid_1's l2: 80.6815
# [22]	training's l2: 90.8963	valid_1's l2: 80.6677
# [23]	training's l2: 90.8766	valid_1's l2: 80.6557
# [24]	training's l2: 90.8568	valid_1's l2: 80.6425
# [25]	training's l2: 90.8375	valid_1's l2: 80.6302
# [26]	training's l2: 90.8185	valid_1's l2: 80.6178
# [27]	training's l2: 90.7995	valid_1's l2: 80.6063
# [28]	training's l2: 90.7813	valid_1's l2: 80.5939
# [29]	training's l2: 90.763	valid_1's l2: 80.5826
# [30]	training's l2: 90.7451	valid_1's l2: 80.5706
# [31]	training's l2: 90.7275	valid_1's l2: 80.5595
# [32]	training's l2: 90.7107	valid_1's l2: 80.5488
# [33]	training's l2: 90.6944	valid_1's l2: 80.5377
# [34]	training's l2: 90.6773	valid_1's l2: 80.5263
# [35]	training's l2: 90.661	valid_1's l2: 80.5161
# [36]	training's l2: 90.6448	valid_1's l2: 80.5067
# [37]	training's l2: 90.6292	valid_1's l2: 80.496
# [38]	training's l2: 90.6132	valid_1's l2: 80.4854
# [39]	training's l2: 90.598	valid_1's l2: 80.4754
# [40]	training's l2: 90.5828	valid_1's l2: 80.4666
# [41]	training's l2: 90.5679	valid_1's l2: 80.4566
# [42]	training's l2: 90.5536	valid_1's l2: 80.4472
# [43]	training's l2: 90.5392	valid_1's l2: 80.4376
# [44]	training's l2: 90.5253	valid_1's l2: 80.4284
# [45]	training's l2: 90.5111	valid_1's l2: 80.4197
# [46]	training's l2: 90.4972	valid_1's l2: 80.4116
# [47]	training's l2: 90.484	valid_1's l2: 80.4032
# [48]	training's l2: 90.4711	valid_1's l2: 80.3961
# [49]	training's l2: 90.4571	valid_1's l2: 80.3881
# [50]	training's l2: 90.4443	valid_1's l2: 80.3802
# [51]	training's l2: 90.4311	valid_1's l2: 80.3735
# [52]	training's l2: 90.4191	valid_1's l2: 80.3662
# [53]	training's l2: 90.4068	valid_1's l2: 80.3584
# [54]	training's l2: 90.3944	valid_1's l2: 80.352
# [55]	training's l2: 90.3824	valid_1's l2: 80.3444
# [56]	training's l2: 90.3705	valid_1's l2: 80.3371
# [57]	training's l2: 90.3582	valid_1's l2: 80.3303
# [58]	training's l2: 90.3455	valid_1's l2: 80.3228
# [59]	training's l2: 90.3338	valid_1's l2: 80.3166
# [60]	training's l2: 90.3222	valid_1's l2: 80.3101
# [61]	training's l2: 90.3111	valid_1's l2: 80.3046
# [62]	training's l2: 90.2996	valid_1's l2: 80.299
# [63]	training's l2: 90.2872	valid_1's l2: 80.2905
# [64]	training's l2: 90.2773	valid_1's l2: 80.2847
# [65]	training's l2: 90.267	valid_1's l2: 80.2781
# [66]	training's l2: 90.2561	valid_1's l2: 80.2726
# [67]	training's l2: 90.2458	valid_1's l2: 80.2669
# [68]	training's l2: 90.2359	valid_1's l2: 80.2613
# [69]	training's l2: 90.2261	valid_1's l2: 80.256
# [70]	training's l2: 90.2161	valid_1's l2: 80.2493
# [71]	training's l2: 90.206	valid_1's l2: 80.2445
# [72]	training's l2: 90.197	valid_1's l2: 80.2391
# [73]	training's l2: 90.1874	valid_1's l2: 80.2345
# [74]	training's l2: 90.1778	valid_1's l2: 80.2293
# [75]	training's l2: 90.1688	valid_1's l2: 80.2237
# [76]	training's l2: 90.1595	valid_1's l2: 80.2197
# [77]	training's l2: 90.1504	valid_1's l2: 80.2146
# [78]	training's l2: 90.1414	valid_1's l2: 80.2108
# [79]	training's l2: 90.1326	valid_1's l2: 80.2058
# [80]	training's l2: 90.1241	valid_1's l2: 80.2017
# [81]	training's l2: 90.1136	valid_1's l2: 80.1972
# [82]	training's l2: 90.1052	valid_1's l2: 80.192
# [83]	training's l2: 90.097	valid_1's l2: 80.1876
# [84]	training's l2: 90.0891	valid_1's l2: 80.1832
# [85]	training's l2: 90.0792	valid_1's l2: 80.1782
# [86]	training's l2: 90.0716	valid_1's l2: 80.1742
# [87]	training's l2: 90.0629	valid_1's l2: 80.1695
# [88]	training's l2: 90.0554	valid_1's l2: 80.1646
# [89]	training's l2: 90.0459	valid_1's l2: 80.1598
# [90]	training's l2: 90.038	valid_1's l2: 80.1565
# [91]	training's l2: 90.0303	valid_1's l2: 80.1519
# [92]	training's l2: 90.0228	valid_1's l2: 80.15
# [93]	training's l2: 90.0155	valid_1's l2: 80.146
# [94]	training's l2: 90.0067	valid_1's l2: 80.1417
# [95]	training's l2: 89.9993	valid_1's l2: 80.1383
# [96]	training's l2: 89.9911	valid_1's l2: 80.1332
# [97]	training's l2: 89.9817	valid_1's l2: 80.1277
# [98]	training's l2: 89.9746	valid_1's l2: 80.1247
# [99]	training's l2: 89.9677	valid_1's l2: 80.1215
# [100]	training's l2: 89.9607	valid_1's l2: 80.1181
# [101]	training's l2: 89.9528	valid_1's l2: 80.1141
# [102]	training's l2: 89.9469	valid_1's l2: 80.111
# [103]	training's l2: 89.9405	valid_1's l2: 80.1078
# [104]	training's l2: 89.9323	valid_1's l2: 80.1049
# [105]	training's l2: 89.9236	valid_1's l2: 80.0998
# [106]	training's l2: 89.9176	valid_1's l2: 80.097
# [107]	training's l2: 89.911	valid_1's l2: 80.0941
# [108]	training's l2: 89.9024	valid_1's l2: 80.0891
# [109]	training's l2: 89.8959	valid_1's l2: 80.0863
# [110]	training's l2: 89.8894	valid_1's l2: 80.0832
# [111]	training's l2: 89.8835	valid_1's l2: 80.0804
# [112]	training's l2: 89.8778	valid_1's l2: 80.078
# [113]	training's l2: 89.8704	valid_1's l2: 80.0737
# [114]	training's l2: 89.8634	valid_1's l2: 80.0697
# [115]	training's l2: 89.8557	valid_1's l2: 80.065
# [116]	training's l2: 89.8486	valid_1's l2: 80.0619
# [117]	training's l2: 89.8418	valid_1's l2: 80.0574
# [118]	training's l2: 89.8357	valid_1's l2: 80.0549
# [119]	training's l2: 89.8304	valid_1's l2: 80.0525
# [120]	training's l2: 89.8243	valid_1's l2: 80.0498
# [121]	training's l2: 89.8178	valid_1's l2: 80.0455
# [122]	training's l2: 89.8113	valid_1's l2: 80.0426
# [123]	training's l2: 89.8054	valid_1's l2: 80.0385
# [124]	training's l2: 89.7999	valid_1's l2: 80.0362
# [125]	training's l2: 89.7937	valid_1's l2: 80.0334
# [126]	training's l2: 89.788	valid_1's l2: 80.0308
# [127]	training's l2: 89.7825	valid_1's l2: 80.0285
# [128]	training's l2: 89.7762	valid_1's l2: 80.026
# [129]	training's l2: 89.7702	valid_1's l2: 80.0233
# [130]	training's l2: 89.7642	valid_1's l2: 80.0193
# [342]	training's l2: 88.9106	valid_1's l2: 79.6705
# [343]	training's l2: 88.907	valid_1's l2: 79.6698
# [344]	training's l2: 88.9038	valid_1's l2: 79.6698
# [345]	training's l2: 88.9013	valid_1's l2: 79.6696
# [346]	training's l2: 88.8978	valid_1's l2: 79.6673
# [347]	training's l2: 88.8944	valid_1's l2: 79.6684
# [348]	training's l2: 88.891	valid_1's l2: 79.6675
# [349]	training's l2: 88.8869	valid_1's l2: 79.6652
# [350]	training's l2: 88.8836	valid_1's l2: 79.6639
# [351]	training's l2: 88.8801	valid_1's l2: 79.6631
# [352]	training's l2: 88.8763	valid_1's l2: 79.6612
# [353]	training's l2: 88.8736	valid_1's l2: 79.6612
# [354]	training's l2: 88.87	valid_1's l2: 79.6614
# [355]	training's l2: 88.8668	valid_1's l2: 79.6602
# [356]	training's l2: 88.8631	valid_1's l2: 79.6594
# [357]	training's l2: 88.8595	valid_1's l2: 79.659
# [358]	training's l2: 88.8557	valid_1's l2: 79.6583
# [359]	training's l2: 88.8521	valid_1's l2: 79.6584
# [360]	training's l2: 88.8487	valid_1's l2: 79.6574
# [361]	training's l2: 88.845	valid_1's l2: 79.6557
# [362]	training's l2: 88.8431	valid_1's l2: 79.6541
# [363]	training's l2: 88.8393	valid_1's l2: 79.6525
# [364]	training's l2: 88.8368	valid_1's l2: 79.6508
# [365]	training's l2: 88.8331	valid_1's l2: 79.6499
# [366]	training's l2: 88.8296	valid_1's l2: 79.6491
# [367]	training's l2: 88.8274	valid_1's l2: 79.649
# [368]	training's l2: 88.8238	valid_1's l2: 79.6488
# [369]	training's l2: 88.8201	valid_1's l2: 79.648
# [370]	training's l2: 88.8167	valid_1's l2: 79.6481
# [371]	training's l2: 88.8137	valid_1's l2: 79.647
# [372]	training's l2: 88.8104	valid_1's l2: 79.6458
# [373]	training's l2: 88.8067	valid_1's l2: 79.6444
# [374]	training's l2: 88.8045	valid_1's l2: 79.6444
# [375]	training's l2: 88.802	valid_1's l2: 79.6435
# [376]	training's l2: 88.7985	valid_1's l2: 79.6439
# [377]	training's l2: 88.7949	valid_1's l2: 79.6422
# [378]	training's l2: 88.7921	valid_1's l2: 79.6404
# [379]	training's l2: 88.7888	valid_1's l2: 79.6399
# [380]	training's l2: 88.7856	valid_1's l2: 79.6403
# [381]	training's l2: 88.7821	valid_1's l2: 79.639
# [382]	training's l2: 88.7784	valid_1's l2: 79.6384
# [383]	training's l2: 88.7762	valid_1's l2: 79.6376
# [384]	training's l2: 88.7733	valid_1's l2: 79.6374
# [385]	training's l2: 88.7691	valid_1's l2: 79.6367
# [386]	training's l2: 88.7658	valid_1's l2: 79.6361
# [387]	training's l2: 88.7631	valid_1's l2: 79.6358
# [388]	training's l2: 88.7597	valid_1's l2: 79.6355
# [389]	training's l2: 88.7563	valid_1's l2: 79.6363
# [390]	training's l2: 88.7533	valid_1's l2: 79.6355
# [391]	training's l2: 88.7509	valid_1's l2: 79.6342
# [392]	training's l2: 88.7474	valid_1's l2: 79.6324
# [393]	training's l2: 88.7439	valid_1's l2: 79.6321
# [394]	training's l2: 88.7415	valid_1's l2: 79.6325
# [395]	training's l2: 88.7382	valid_1's l2: 79.6304
# [396]	training's l2: 88.735	valid_1's l2: 79.6299
# [397]	training's l2: 88.7318	valid_1's l2: 79.6292
# [398]	training's l2: 88.7285	valid_1's l2: 79.6282
# [399]	training's l2: 88.7255	valid_1's l2: 79.6271
# [400]	training's l2: 88.7226	valid_1's l2: 79.6267
# Did not meet early stopping. Best iteration is:
# [400]	training's l2: 88.7226	valid_1's l2: 79.6267

# %%
y_pred_valid = model.predict(X_valid)

y_pred_valid = np.nan_to_num(y_pred_valid)
y_valid = np.nan_to_num(y_valid)
mae = mean_absolute_error(y_valid, y_pred_valid)
print(f"score MAE {mae}")
# Out:
# score MAE 5.99578224263733

# %%
#Pour la soumission on instancie l'env et le fichier de test
env = optiver2023.make_env()
iter_test = env.iter_test()

# %%
counter = 0
for (test, revealed_targets, sample_prediction) in iter_test:
    sample_prediction['target'] = model.predict(test.drop('row_id', axis = 1))
    env.predict(sample_prediction)
    counter += 1
# Out:
# This version of the API is not optimized and should not be used to estimate the runtime of your code on the hidden test set.

# %% [markdown]
# ## 2.3. Improved LightGBM Solution

# %%
# def calculate_imbalance_features(df):
#     # Calculate and add imbalance feature 1 (imb_s1)
#     df['imb_s1'] = df.eval('(bid_size - ask_size) / (bid_size + ask_size)')  

#     # Calculate and add imbalance feature 2 (imb_s2)
#     df['imb_s2'] = df.eval('(imbalance_size - matched_size) / (matched_size + imbalance_size)') 

#     return df

# %%
# estimator = lightgbm.LGBMRegressor(
#     boosting_type='gbdt', 
#     num_leaves=31, 
#     max_depth=-1, 
#     learning_rate=0.1, 
#     n_estimators=100, 
#     subsample_for_bin=200000, 
#     objective='mae', 
#     class_weight=None, 
#     min_split_gain=0.0, 
#     min_child_weight=0.001, 
#     min_child_samples=20, 
#     subsample=1.0, 
#     subsample_freq=0, 
#     colsample_bytree=1.0, 
#     reg_alpha=0.0, 
#     reg_lambda=0.0, 
#     random_state=SEED, 
#     n_jobs=-1, 
#     importance_type='split',
#     force_row_wise=True
# )

# val_predictions = np.zeros(len(X_train))
# val_scores = []

# splitter = sk.model_selection.TimeSeriesSplit(5).split(X_train, y_train)

# for fold, (train_idx, val_idx) in enumerate(splitter):
#     model = sk.base.clone(estimator)

#     # Define train and val set
#     X_train = X_train.iloc[train_idx]
#     y_train = y_train.iloc[train_idx]
#     X_val = X_train.iloc[val_idx]
#     y_val = y_train.iloc[val_idx]

#     model.fit(X_train, y_train)
#     val_scores.append(sk.metrics.mean_absolute_error(model.predict(X_val), y_val))

# print(f'Val Score: {np.mean(val_scores):.2f} ± {np.std(val_scores):.5f}')

# %%
# import optiver2023

# env = optiver2023.make_env()
# iter_test = env.iter_test()

# model.fit(X_train, y_train)

# counter = 0
# for (test, revealed_targets, sample_prediction) in iter_test:
#     sample_prediction['target'] = model.predict(test.drop('row_id', axis = 1))
#     env.predict(sample_prediction)
#     counter += 1

# %% [markdown]
# # 3. Final Thoughts

# %%
END = pd.Timestamp.now()
time_elapsed = (END - START).total_seconds()
print(f"Notebook Total Time: {time_elapsed:.2f}s")
